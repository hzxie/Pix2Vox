# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
image_filename = '/home/sidroy/software/Pix2Vox/datasets/Pix3D/img/chair/0516.jpg'
mask_filename = '/home/sidroy/software/Pix2Vox/datasets/Pix3D/mask/chair/0516.png'

# %% [markdown]
# Open the image

# %%
from PIL import Image
from torchvision import transforms
# Input image is opened in this line
input_image = Image.open(image_filename)
print("Shape of Input Image {}".format(input_image.size))
dim_input_image = len(input_image.size)

# convert input image to numpy array and seperate the color channels
image_array = np.array(input_image)
print('Shape of Image Array is {}'.format(image_array.shape))
b_channel, g_channel, r_channel = cv2.split(image_array)
# Out:
# Shape of Input Image (3024, 4032)
# Shape of Image Array is (4032, 3024, 3)

# %% [markdown]
# Open the mask

# %%
# Input image is opened in this line
input_mask = Image.open(mask_filename)
print("Shape of Input Image {}".format(input_mask.size))
dim_input_mask = len(input_mask.size)

# convert the input mask to numpy array
mask_array = np.array(input_mask)
mask_array[1500,1500]
# Out:
# Shape of Input Image (3024, 4032)
# 255

# %% [markdown]
# ### Merge the input image array RGB channels and the alpha/mask channel

# %%
img_BGRA = cv2.merge((b_channel, g_channel, r_channel, mask_array))
img_RGBA = cv2.merge(( r_channel, g_channel, b_channel, mask_array))
# %matplotlib notebook
plt.imshow(img_BGRA)
plt.show()
cv2.imwrite('out.png', img_RGBA)
# Out:
# <img src="data:image/png;base64,..." width="639.230792677615">
# True

# %% [markdown]
# ### Converting RGB image to grayscale

# %%
gray = cv2.cvtColor(image_array, cv2.COLOR_BGR2GRAY)
img_RGBA = cv2.merge(( gray, gray, gray, a_channel))
# %matplotlib notebook
plt.imshow(img_RGBA)
plt.show()
cv2.imwrite('gray_out.png', img_RGBA)
# Out:
# <img src="data:image/png;base64,..." width="639.230792677615">
# True

# %% [markdown]
# ## Check the format of the shapenet input image format

# %%
shapenet_filename = '/home/sidroy/Insight/projects/Pix2Vox/LargeDatasets/ShapeNetRendering/02958343/1a0bc9ab92c915167ae33d942430658c/rendering/00.png'
modified_shapenet_file = 'shapenet_image.png'

# %%
input_image = Image.open(modified_shapenet_file)
print("Shape of Input Image {}".format(input_image.size))
dim_input_image = len(input_image.size)

# convert input image to numpy array and seperate the color channels
image_array = np.array(input_image)
print('Shape of Image Array is {}'.format(image_array.shape))
b_channel, g_channel, r_channel, a_channel = cv2.split(image_array)
# Out:
# Shape of Input Image (500, 500)
# Shape of Image Array is (500, 500, 4)

# %%
img_RGBA = cv2.merge(( r_channel, g_channel, b_channel, a_channel))
img_BGRA = cv2.merge((b_channel, g_channel, r_channel, a_channel))
# %matplotlib notebook
plt.imshow(img_BGRA)
plt.show()
cv2.imwrite('shapenet_image.png', img_RGBA)
# Out:
# <img src="data:image/png;base64,..." width="639.230792677615">
# True

# %%
r_channel.shape
# Out:
# (137, 137)

# %%
segmented_filename = '/home/sidroy/Insight/projects/Pix2Vox/out.png'

# %%
segmented_image = Image.open(segmented_filename)
print("Shape of Segmented Image {}".format(segmented_image.size))
dim_segmented_image = len(segmented_image.size)

# convert input image to numpy array and seperate the color channels
seg_image_array = np.array(segmented_image)
print('Shape of Image Array is {}'.format(seg_image_array.shape))
seg_b_channel, seg_g_channel, seg_r_channel, seg_a_channel = cv2.split(seg_image_array)
# Out:
# Shape of Segmented Image (3024, 4032)
# Shape of Image Array is (4032, 3024, 4)
