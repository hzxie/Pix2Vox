# %%
import json

# %%
json.load(ShapeNet.json)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4421dca76b99> in <module>
# ----> 1 json.load(ShapeNet.json)
#
# NameError: name 'ShapeNet' is not defined

# %%
with open('./ShapeNet.json','r') as file:
    data = json.load(file)

# %%
type(data)
# Out:
# list

# %%
data
# Out:
# [{'taxonomy_id': '02691156',
#   'taxonomy_name': 'aeroplane',
#   'baseline': {'1-view': 0.513,
#    '2-view': 0.536,
#    '3-view': 0.549,
#    '4-view': 0.556,
#    '5-view': 0.561},
#   'test': ['6c432109eee42aed3b053f623496d8f5',
#    'a9b95631bcbefe9ad225a1c252daae25',
#    '5d8583703889178a8bc354dd4eb23614',
#    '8996445c6d2407c0fb5c1b0f759e2bc1',
#    '2ef20ad4c579812571d03b466c72ce41',
#    '63a2144cfae402149b30aa09067b7eef',
#    '2677c3793143e75766cf1b4a8fc3914e',
#    '460cf3a75d8467d1bb579d1d8d989550',
#    '6946f7a2a5ef851215ea536736a1eb7e',
#    'a1b95d2e1264f6bd66ccbd11a6ef0f68',
#    'b501466a5a77f1173d2cc3e9d55f7579',
#    'fdb107ea7a600f5fe3f3aec01b086ba',
#    'a20490d0ffcd3be6e0d6812cdcf8799b',
#    '20865546e07ab8067c597cd12d99981b',
#    '464879f87b67827af268234accd8cf4e',
#    '13ea0a2ac279dbaa5e9e2656aff7dd5b',
#    'da9c541228a171b7ca8607f540cc62ba',
#    '87edb38cd76e89f5996d31205aa7f7a',
#    '8b59ed9a391c86cdb4910ab5b756f3ae',
# ...

# %%
type(data)
# Out:
# list

# %%
print(data[3]['taxonomy_id'])
print(data[3]['taxonomy_name'])
data[3]['train']
# Out:
# 02958343
# car
# ['baa916a641aca34521a66e8dfcce514a',
#  'ab2759c8e0cf3b8da9d243597c4c2c2e',
#  '9232d8834704e5f9dd141480e2c154d3',
#  '5fc83a88645b1869514e3d96995c555d',
#  '8320c70894c3cdfdff1370452e3a0154',
#  'f06af3b73004c92ec7193c87bbfa9088',
#  'f0fe905b24379dfaa9fe1734a6086750',
#  '79bf4c4574bc9c4552470de2774d6099',
#  'c2283d62367d637249b991141ee51d9a',
#  '302612708e86efea62d2c237bfbc22ca',
#  '91479065c2195c2f43abe9ab013b8352',
#  '54151e59eb9eeb36ca2b6e5474aad11',
#  '804f736d7010d37a85dda3b11bec9128',
#  'cc7f51159a1a12fea7fd25564c2e888e',
#  '7c35cd27ae8d673bb1bb46d2556ba67d',
#  'b4ca1d3ef64d405a2a7ed5067bf29e0e',
#  'f75a99fe678bfd98df8e4da0a37cb43e',
#  '379a741bc285409a1a0cb0f1720d27f1',
#  '2c981b96364b1baa21a66e8dfcce514a',
#  'b8cee2711b84bebb425b2c354eccabaf',
#  'b5467609320e6577e6f4ca3383205eb',
#  '16bd0438de54fc91b1bb46d2556ba67d',
#  'fcd90d547fdeb629f200a72c9245aee7',
#  'e60598d4462b852411fae996ae9899df',
#  'e2a4635c392e750abecf71e2e014ff6f',
# ...

# %%
demo_data = [{'taxonomy_id': 'car',
  'taxonomy_name': 'car',
  'baseline': {'1-view': 0.798,
 '2-view': 0.821,
 '3-view': 0.829,
 '4-view': 0.833,
 '5-view': 0.836},
  'test': ['car_subfolder']}]

# %%
with open('DemoData.json', 'w') as f:
    json.dump(demo_data, f)

# %%
demo_data
# Out:
# [{'taxonomy_id': 'car',
#   'taxonomy_name': 'car',
#   'baseline': {'1-view': 0.798,
#    '2-view': 0.821,
#    '3-view': 0.829,
#    '4-view': 0.833,
#    '5-view': 0.836},
#   'test': ['car_subfolder']}]
